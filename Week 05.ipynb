# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data.csv')

# %%
data
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
data[(data["Assignment 1"] >= 7) ].count()
# Out:
# Student Code            6
# Degree                  6
# Student Name            6
# Mid                     6
# Quiz 1                  6
# Quiz 2                  6
# Best of Quizzes         6
# Assignment 1            6
# Assignment 2            5
# Best of Assignments     6
# Total Sessional (50)    6
# Final (50)              6
# Total (100)             6
# Grade                   6
# dtype: int64

# %%
names=data[(data["Assignment 1"]>=7)& (data["Assignment 2"]>=7)]["Student Name"]
names
# Out:
# 0                        Abdul Basit
# 1                        Adeel Ahmed
# 2                       Afrah Zareen
# 4                    Ahsan Ali Vohra
# 5                        Ameer Hamza
# 6                      Anas Ali Khan
# 7                   Aneebullah Niazi
# 8                     Areesha Sohail
# 12               Hafiza Tooba Akbani
# 13                Hamza Abdul Jabbar
# 16                      Hassam Ahmed
# 17                      Khalid Anwer
# 18                     Madiha Jabeen
# 19                   Mohammad Hunain
# 20                    Muhammad Aamir
# 21    Muhammad Abdul Rehman Siddiqui
# 23                Muhammad Ali Iqbal
# 24                    Muhammad Bilal
# 25                    Muhammad Faraz
# 27               Muhammad Osama Khan
# 28            Muhammad Saqib Intizar
# 32             Muhammad Wajahat Khan
# 33              Muhammad Younus Baig
# 34                  Nazeer Bin Zafar
# 39                       Sania Iqbal
# ...

# %%
for i in names:
    i=str(i)
    if i.startswith("Muhammad") or i.startswith("Mohammad"):
        print(i)
# Out:
# Mohammad Hunain
# Muhammad Aamir
# Muhammad Abdul Rehman Siddiqui
# Muhammad Ali Iqbal
# Muhammad Bilal
# Muhammad Faraz
# Muhammad Osama Khan
# Muhammad Saqib Intizar
# Muhammad Wajahat Khan
# Muhammad Younus Baig

# %%
x =  pd.Series(range(6), index=['a','b','c','d','1','A'])

# %%
y = pd.DataFrame(range(4,2),  index=["one", "two"], columns= ["a","b","c","d"])
y.loc["one"]=[1,9,6,7]
y.loc["two"]=[8,4,16,13]
y
# Out:
#      a  b   c   d
# one  1  9   6   7
# two  8  4  16  13

# %%
y.sort_index(axis=0, ascending=False, inplace=True)
y
# Out:
#      a  b   c   d
# two  8  4  16  13
# one  1  9   6   7

# %%
data[data["Assignment 1"].isin([8,9])]   #retrieve data on the specific values of coloumn for entire dataFrame
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 12  022-15-110994  BS(CS)             Hafiza Tooba Akbani   23     7.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# 17  022-14-110396  BS(CS)                    Khalid Anwer   20     8.0
# 18  022-14-110223  BS(CS)                   Madiha Jabeen   16     5.0
# 19  022-14-110222  BS(CS)                 Mohammad Hunain   27     9.0
# ...
